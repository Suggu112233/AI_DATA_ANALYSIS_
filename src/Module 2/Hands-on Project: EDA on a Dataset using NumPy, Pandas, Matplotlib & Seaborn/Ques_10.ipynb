# %%
# Step 1: Set Up the Environment
# Objective: Ensure you have the right tools and packages installed.

# 1. Install the required libraries.
# 2. Verify the installation by importing the libraries in a Python script or Jupyter notebook





# Step 2: Load & Explore the Dataset
# Objective: Load data into a pandas DataFrame and obtain a basic understanding of its structure.

# 3. Load a CSV file into a DataFrame.
# 4. Display the first few records to understand the structure.
# 5. Get a summary of the dataset.






# Step 3: Perform NumPy Operations
# Objective: Utilize NumPy for basic numerical operations and array manipulations.

# 6. Convert a DataFrame column to a NumPy array and perform array operations like mean and sum.
# 7. Create a NumPy array and calculate the variance and standard deviation.
# 8. Use NumPy to filter based on conditions.








# Step 4: Data Manipulation with Pandas
# Objective: Use Pandas to clean and manipulate dataset for analysis.

# 9. Handle missing data by filling or dropping.
# 10. Create new columns or modify existing ones.
# 11. Use groupby to aggregate data.







# Step 5: Data Visualization with Matplotlib & Seaborn
# Objective: Visualize the data to identify patterns, trends, and insights.

# 12. Use Matplotlib to create a basic plot.
# 13. Create a histogram using Seaborn.
# 14. Plot a box plot for a clear view of data distribution.


# Step 1: Set Up the Environment
# Objective: Ensure you have the right tools and packages installed.

# 1. (Optional) Install required libraries
# !pip install pandas numpy matplotlib seaborn

# 2. Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 2: Load & Explore the Dataset
# Objective: Load data into a pandas DataFrame and obtain a basic understanding of its structure.

# 3. Load CSV into DataFrame
df = pd.read_csv('grouped_mean_by_species.csv')

# 4. Display the first few records
print("First few rows of the dataset:")
print(df.head())

# 5. Get a summary of the dataset
print("\nSummary of the dataset:")
print(df.info())

# Step 3: Perform NumPy Operations
# Objective: Utilize NumPy for basic numerical operations and array manipulations.

# 6. Convert a DataFrame column (example: 'mean_weight') to NumPy array and perform mean/sum
if 'mean_weight' in df.columns:
    weights_array = df['mean_weight'].to_numpy()
    print("\nNumPy array (mean_weight):", weights_array)
    print("Mean of mean_weight:", np.mean(weights_array))
    print("Sum of mean_weight:", np.sum(weights_array))
else:
    print("\nColumn 'mean_weight' not found.")

# 7. Create a NumPy array manually and calculate variance/std deviation
manual_array = np.array([10, 20, 30, 40, 50])
print("\nManual array:", manual_array)
print("Variance:", np.var(manual_array))
print("Standard Deviation:", np.std(manual_array))

# 8. Use NumPy to filter values greater than a threshold (e.g. mean_weight > 50)
if 'mean_weight' in df.columns:
    filtered = df[df['mean_weight'] > 50]
    print("\nFiltered rows where mean_weight > 50:")
    print(filtered)

# Step 4: Data Manipulation with Pandas
# Objective: Use Pandas to clean and manipulate dataset for analysis.

# 9. Handle missing data
print("\nMissing data summary:")
print(df.isnull().sum())

# Fill missing values with mean (example for 'mean_weight')
if 'mean_weight' in df.columns:
    df['mean_weight'].fillna(df['mean_weight'].mean(), inplace=True)

# 10. Create a new column (e.g., "scaled_weight")
if 'mean_weight' in df.columns:
    df['scaled_weight'] = df['mean_weight'] / df['mean_weight'].max()

# 11. Use groupby (example: group by 'species' and get average weight)
if 'species' in df.columns and 'mean_weight' in df.columns:
    grouped = df.groupby('species')['mean_weight'].mean()
    print("\nGrouped mean weight by species:")
    print(grouped)

# Step 5: Data Visualization with Matplotlib & Seaborn
# Objective: Visualize the data to identify patterns, trends, and insights.

# 12. Matplotlib basic plot (e.g., species vs mean_weight)
if 'species' in df.columns and 'mean_weight' in df.columns:
    plt.figure(figsize=(8, 5))
    plt.bar(df['species'], df['mean_weight'], color='skyblue')
    plt.xlabel("Species")
    plt.ylabel("Mean Weight")
    plt.title("Mean Weight by Species")
    plt.xticks(rotation=45)
    plt.grid(True, axis='y', linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# 13. Histogram using Seaborn
if 'mean_weight' in df.columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(df['mean_weight'], bins=10, kde=True, color='green')
    plt.title("Distribution of Mean Weight")
    plt.xlabel("Mean Weight")
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

# 14. Box plot
if 'mean_weight' in df.columns:
    plt.figure(figsize=(6, 4))
    sns.boxplot(y=df['mean_weight'], color='orange')
    plt.title("Box Plot of Mean Weight")
    plt.ylabel("Mean Weight")
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 74
#      68 import seaborn as sns
#      70 # Step 2: Load & Explore the Dataset
#      71 # Objective: Load data into a pandas DataFrame and obtain a basic understanding of its structure.
#      72
#      73 # 3. Load CSV into DataFrame
# ---> 74 df = pd.read_csv('grouped_mean_by_species.csv')
#      76 # 4. Display the first few records
#      77 print("First few rows of the dataset:")
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
df = sns.load_dataset('iris')

# %%
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# ...

# %%
arr = df['sepal_length'].to_numpy()  # Example column
print("Mean:", np.mean(arr))
print("Sum:", np.sum(arr))
# Out:
# Mean: 5.843333333333334
# Sum: 876.5

# %%
arr2 = df['sepal_width'].to_numpy()
print("Variance:", np.var(arr2))
print("Standard Deviation:", np.std(arr2))
# Out:
# Variance: 0.1887128888888889
# Standard Deviation: 0.4344109677354946

# %%
filtered = arr[arr > 5.0]
print("Values greater than 5.0:", filtered)
# Out:
# Values greater than 5.0: [5.1 5.4 5.4 5.8 5.7 5.4 5.1 5.7 5.1 5.4 5.1 5.1 5.2 5.2 5.4 5.2 5.5 5.5
#  5.1 5.1 5.1 5.3 7.  6.4 6.9 5.5 6.5 5.7 6.3 6.6 5.2 5.9 6.  6.1 5.6 6.7
#  5.6 5.8 6.2 5.6 5.9 6.1 6.3 6.1 6.4 6.6 6.8 6.7 6.  5.7 5.5 5.5 5.8 6.
#  5.4 6.  6.7 6.3 5.6 5.5 5.5 6.1 5.8 5.6 5.7 5.7 6.2 5.1 5.7 6.3 5.8 7.1
#  6.3 6.5 7.6 7.3 6.7 7.2 6.5 6.4 6.8 5.7 5.8 6.4 6.5 7.7 7.7 6.  6.9 5.6
#  7.7 6.3 6.7 7.2 6.2 6.1 6.4 7.2 7.4 7.9 6.4 6.3 6.1 7.7 6.3 6.4 6.  6.9
#  6.7 6.9 5.8 6.8 6.7 6.7 6.3 6.5 6.2 5.9]

# %%
numeric_cols = df.select_dtypes(include=np.number).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# %%
df['petal_length_to_width_ratio'] = df['petal_length'] / df['petal_width']

# %%
grouped = df.groupby('species').mean()
print(grouped)
# Out:
#             sepal_length  sepal_width  petal_length  petal_width  \
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026
#
#             petal_length_to_width_ratio
# species
# setosa                         6.908000
# versicolor                     3.242837
# virginica                      2.780662

# %%
grouped['sepal_length'].plot(kind='bar')
plt.title('Average Sepal Length by Species')
plt.ylabel('Sepal Length (cm)')
plt.show()

# %%
sns.histplot(df['sepal_length'], kde=True)
plt.title('Distribution of Sepal Length')
plt.show()

# %%
sns.boxplot(x='species', y='petal_length', data=df)
plt.title('Petal Length Distribution by Species')
plt.show()
