# %%
# Title: Data Manipulation with Pandas
# Description: Add a new column that calculates the ratio of petal length to petal width.

# %%
import seaborn as sns
import pandas as pd

# Load the iris dataset
iris = sns.load_dataset('iris')

# Add new column 'petal_ratio' = petal_length / petal_width
iris['petal_ratio'] = iris['petal_length'] / iris['petal_width']

# Display first 5 rows to verify
print(iris.head())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import seaborn as sns
#       2 import pandas as pd
#       4 # Load the iris dataset
#
# File ~/.local/lib/python3.10/site-packages/seaborn/__init__.py:5
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
# ----> 5 from .relational import *  # noqa: F401,F403
#       6 from .regression import *  # noqa: F401,F403
#       7 from .categorical import *  # noqa: F401,F403
#
# File ~/.local/lib/python3.10/site-packages/seaborn/relational.py:21
#      13 from .utils import (
#      14     adjust_legend_subtitles,
#      15     _default_color,
#    (...)
#      18     _scatter_legend_artist,
#      19 )
#      20 from ._compat import groupby_apply_include_groups
# ---> 21 from ._statistics import EstimateAggregator, WeightedAggregator
#      22 from .axisgrid import FacetGrid, _facet_docs
#      23 from ._docstrings import DocstringComponents, _core_docs
#
# File ~/.local/lib/python3.10/site-packages/seaborn/_statistics.py:32
#      30 import pandas as pd
#      31 try:
# ---> 32     from scipy.stats import gaussian_kde
#      33     _no_scipy = False
#      34 except ImportError:
#
# File ~/.local/lib/python3.10/site-packages/scipy/stats/__init__.py:624
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     619
#     620 """  # noqa: E501
#     622 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     623                                DegenerateDataWarning, FitError)
# --> 624 from ._stats_py import *
#     625 from ._variation import variation
#     626 from .distributions import *
#
# File ~/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:52
#      49 # Import unused here but needs to stay until end of deprecation periode
#      50 # See https://github.com/scipy/scipy/issues/15765#issuecomment-1875564522
#      51 from scipy import linalg  # noqa: F401
# ---> 52 from . import distributions
#      53 from . import _mstats_basic as mstats_basic
#      55 from ._stats_mstats_common import _find_repeats, theilslopes, siegelslopes
#
# File ~/.local/lib/python3.10/site-packages/scipy/stats/distributions.py:10
#       1 #
#       2 # Author:  Travis Oliphant  2002-2011 with contributions from
#       3 #          SciPy Developers 2004-2011
#    (...)
#       6 #       instead of `git blame -Lxxx,+x`.
#       7 #
#       8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)  # noqa: F401
# ---> 10 from . import _continuous_distns
#      11 from . import _discrete_distns
#      13 from ._continuous_distns import *  # noqa: F403
#
# File ~/.local/lib/python3.10/site-packages/scipy/stats/_continuous_distns.py:10008
#   10004         warnings.warn(deprmsg, DeprecationWarning, stacklevel=2)
#   10005         return self.freeze(*args, **kwds)
# > 10008 trapezoid = trapezoid_gen(a=0.0, b=1.0, name="trapezoid")
#   10009 trapz = trapz_gen(a=0.0, b=1.0, name="trapz")
#   10011 # since the deprecated class gets intantiated upon import (and we only want to
#   10012 # warn upon use), add the deprecation to each class method
#
# File ~/.local/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:1877, in rv_continuous.__init__(self, momtype, a, b, xtol, badvalue, name, longname, shapes, seed)
#    1872 self.shapes = shapes
#    1874 self._construct_argparser(meths_to_inspect=[self._pdf, self._cdf],
#    1875                           locscale_in='loc=0, scale=1',
#    1876                           locscale_out='loc, scale')
# -> 1877 self._attach_methods()
#    1879 if longname is None:
#    1880     if name[0] in ['aeiouAEIOU']:
#
# File ~/.local/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:1911, in rv_continuous._attach_methods(self)
#    1907 """
#    1908 Attaches dynamically created methods to the rv_continuous instance.
#    1909 """
#    1910 # _attach_methods is responsible for calling _attach_argparser_methods
# -> 1911 self._attach_argparser_methods()
#    1913 # nin correction
#    1914 self._ppfvec = vectorize(self._ppf_single, otypes='d')
#
# File ~/.local/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:735, in rv_generic._attach_argparser_methods(self)
#     727 """
#     728 Generates the argument-parsing functions dynamically and attaches
#     729 them to the instance.
#    (...)
#     732 during unpickling (__setstate__)
#     733 """
#     734 ns = {}
# --> 735 exec(self._parse_arg_template, ns)
#     736 # NB: attach to the instance, not class
#     737 for name in ['_parse_args', '_parse_args_stats', '_parse_args_rvs']:
#
# File <string>:1
#
# KeyboardInterrupt:
